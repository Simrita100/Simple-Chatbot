# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
reflections = {
  "I am"       : "you are",
  "I was"      : "you were",
  "I"          : "you",
  "I'm"        : "you are",
  "I'd"        : "you would",
  "I've"       : "you have",
  "I'll"       : "you will",
  "my"         : "your",
  "you are"    : "I am",
  "you were"   : "I was",
  "you've"     : "I have",
  "you'll"     : "I will",
  "your"       : "my",
  "yours"      : "mine",
  "you"        : "me",
  "me"         : "you"
}

# %%
commands = [
    [
        r"my name is (.*)",
        ["Hello %1, How are you today ?",]
    ],
    [
        r"hi|hey|hello",
        ["Hello", "Hey there",]
    ], 
    [
        r"what is your name ?",
        ["I am a Chatbot created by Simrita. you can call me ROBO! 👾",]
    ],
    [
        r"how are you ?",
        ["I'm doing goodnHow about You ?",]
    ],
    [
        r"sorry",
        ["Its alright","Its OK, never mind",]
    ],
    [
        r"I am fine",
        ["Great to hear that, How can I help you?",]
    ],
    [
        r"i'm doing good",
        ["Nice to hear that","How can I help you?:)",]
    ],
    [
        r"(.*) age?",
        ["I'm a computer program , haha 😂",]
    ],
    [
        r"what (.*) want ?",
        ["Make me an offer I can't refuse",]
    ],
    [
        r"(.*) created ?",
        ["I was created by using Python's NLTK library ","top secret ;)",]
    ],
    [
        r"(.*) (location|city) ?",
        ['Bhubaneswar, Odisha',]
    ],
    [
        r"how is the weather in (.*)?",
        ["Weather in %1 is awesome like always","Too cold in here %1","Too hot in here %1","Never even heard about %1"]
    ],
    [
        r"I work in (.*)?",
        ["%1 is an Amazing company, I have heard about it.",]
    ],
    [
        r"(.*)raining in (.*)",
        ["No rain since last week here in %2","Damn its raining too much here in %2"]
    ],
    [
        r"how (.*) health(.*)",
        ["I'm a computer program, so I'm always healthy ",]
    ],
    [
        r"(.*) (sports|game) ?",
        ["I'm a very big fan of Swimming and Football 🤽🏻‍♂️, ⚽"]
    ],
    [
        r"who (.*) sportsperson ?",
        ["Michael Phelpa","Ronaldo","Missy Franklin"]
    ],
    [
        r"who (.*) (moviestar|actor)?",
        ["Benedict Cumberbatch"]
    ],
    [
        r"I am looking for online guides and courses to learn data science, can you suggest?",
        ["Many online websites are available these days, great articles with each step explanation along with code, you can explore"]
    ],
    [
        r"quit",
        ["Bye take care. See you soon :) ","It was nice talking to you. See you soon 😊"]
    ],
]

# %%
def chat():
    print("Hi! I am a chatbot created by Simrita for your service")
    chat = Chat(commands, reflections)
    chat.converse()
#initiate the conversation
if __name__ == "__main__":
    chat()
# Out:
# Hi! I am a chatbot created by Simrita for your service
# >simmooooooo
# None
# >hi
# Hello
# >hello
# Hey there
# >how are you
# I'm doing goodnHow about You ?
# >i am fine
# Great to hear that, How can I help you?
# >what are you doing
# None
# >whats up
# None
# >
# >
# >what's up
# None
# >hi baby
# Hey there
# >what is your name
# I am a Chatbot created by Simrita. you can call me ROBO! 👾
# >hello robo
# Hey there
# >lets have some fun
# None
# >what is your age
# I'm a computer program , haha 😂
# >what do you like
# None
# >sorry
# Its OK, never mind
# >who is your favorite actor
# Benedict Cumberbatch
# >what is your favorite game
# I'm a very big fan of Swimming and Football 🤽🏻‍♂️, ⚽
# >quit
# Bye take care. See you soon :)
